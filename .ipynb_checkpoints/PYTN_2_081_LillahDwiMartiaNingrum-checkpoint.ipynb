# %% [markdown]
# # DATA VISUALIZATION BOOKING PRODUCT HETO 2017-2021

# %%
import numpy as np
import pandas as pd
import math
import statistics
import seaborn as sns
import statistics as stats
import scipy.stats
from scipy.stats import uniform
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.style.use(['ggplot'])
# %matplotlib inline

# %%
df = pd.read_csv('DATASETHETO.csv')
print ('Data read into a pandas dataframe!')
# Out:
# Data read into a pandas dataframe!

# %%
df.head(5)
# Out:
#    Year         Semester   Quarter Month       Branch Customer Economy Sector  \
# 0  2017  Semester-1 2017  Q-1 2017  Jan    BALIKPAPAN            PERTAMBANGAN
# 1  2017  Semester-1 2017  Q-1 2017  Jan    BALIKPAPAN            PERTAMBANGAN
# 2  2017  Semester-1 2017  Q-1 2017  Jan    BALIKPAPAN            PERTAMBANGAN
# 3  2017  Semester-1 2017  Q-1 2017  Jan    BALIKPAPAN            PERTAMBANGAN
# 4  2017  Semester-1 2017  Q-1 2017  Jan       BANDUNG            PERTAMBANGAN
#
#   Industry Type Group  Customer Industry Type  Booking Contract  \
# 0           BATU BARA        KONTRAKTOR UTAMA                 5
# 1           BATU BARA        KONTRAKTOR UTAMA                 5
# 2           BATU BARA  RENTAL HEAVY EQUIPMENT                 4
# 3           BATU BARA  RENTAL HEAVY EQUIPMENT                 4
# 4        PASIR & BATU          SUB KONTRAKTOR                 1
#
#    Booking NTF Amount
# 0        5.428000e+09
# 1        5.428000e+09
# 2        9.800000e+08
# 3        9.800000e+08
# 4        9.503835e+08

# %%
df.tail(5)
# Out:
#       Year         Semester   Quarter Month      Branch  \
# 9982  2021  Semester-2 2021  Q-4 2021  Dec    TANGERANG
# 9983  2021  Semester-2 2021  Q-4 2021  Dec    TANGERANG
# 9984  2021  Semester-2 2021  Q-4 2021  Dec    TANGERANG
# 9985  2021  Semester-2 2021  Q-4 2021  Dec    TANGERANG
# 9986  2021  Semester-2 2021  Q-4 2021  Dec    TANGERANG
#
#      Customer Economy Sector Industry Type Group  Customer Industry Type  \
# 9982            PERTAMBANGAN        PASIR & BATU  RENTAL HEAVY EQUIPMENT
# 9983               KONTRUKSI          KONSTRUKSI  RENTAL HEAVY EQUIPMENT
# 9984               KONTRUKSI          KONSTRUKSI  RENTAL HEAVY EQUIPMENT
# 9985               KONTRUKSI          KONSTRUKSI          SUB KONTRAKTOR
# 9986               KONTRUKSI          KONSTRUKSI          SUB KONTRAKTOR
#
#       Booking Contract  Booking NTF Amount
# 9982                 1        1.133403e+09
# 9983                 1        3.760600e+08
# 9984                 1        3.760600e+08
# 9985                 2        3.593805e+08
# 9986                 2        3.593805e+08

# %%
df.shape
# Out:
# (9987, 10)

# %%
#Menghilangkan Kolom Yang Tidak Perlu#
data =df.drop(['Semester', 'Quarter', 'Customer Industry Type'], axis=1)
data
# Out:
#       Year Month       Branch Customer Economy Sector Industry Type Group  \
# 0     2017  Jan    BALIKPAPAN            PERTAMBANGAN           BATU BARA
# 1     2017  Jan    BALIKPAPAN            PERTAMBANGAN           BATU BARA
# 2     2017  Jan    BALIKPAPAN            PERTAMBANGAN           BATU BARA
# 3     2017  Jan    BALIKPAPAN            PERTAMBANGAN           BATU BARA
# 4     2017  Jan       BANDUNG            PERTAMBANGAN        PASIR & BATU
# ...    ...   ...          ...                     ...                 ...
# 9982  2021  Dec     TANGERANG            PERTAMBANGAN        PASIR & BATU
# 9983  2021  Dec     TANGERANG               KONTRUKSI          KONSTRUKSI
# 9984  2021  Dec     TANGERANG               KONTRUKSI          KONSTRUKSI
# 9985  2021  Dec     TANGERANG               KONTRUKSI          KONSTRUKSI
# 9986  2021  Dec     TANGERANG               KONTRUKSI          KONSTRUKSI
#
#       Booking Contract  Booking NTF Amount
# 0                    5        5.428000e+09
# 1                    5        5.428000e+09
# 2                    4        9.800000e+08
# 3                    4        9.800000e+08
# 4                    1        9.503835e+08
# ...                ...                 ...
# 9982                 1        1.133403e+09
# 9983                 1        3.760600e+08
# 9984                 1        3.760600e+08
# 9985                 2        3.593805e+08
# 9986                 2        3.593805e+08
#
# [9987 rows x 7 columns]

# %%
data.isnull().sum()
# Out:
# Year                       0
# Month                      0
# Branch                     0
# Customer Economy Sector    0
# Industry Type Group        0
# Booking Contract           0
# Booking NTF Amount         0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9987 entries, 0 to 9986
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Year                     9987 non-null   int64
#  1   Month                    9987 non-null   object
#  2   Branch                   9987 non-null   object
#  3   Customer Economy Sector  9987 non-null   object
#  4   Industry Type Group      9987 non-null   object
#  5   Booking Contract         9987 non-null   int64
#  6   Booking NTF Amount       9987 non-null   float64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 546.3+ KB

# %%
data['Booking NTF Amount'] = pd.to_numeric(data['Booking NTF Amount'], errors='coerce').convert_dtypes()

# %%
data.head(5)
# Out:
#    Year Month       Branch Customer Economy Sector Industry Type Group  \
# 0  2017  Jan    BALIKPAPAN            PERTAMBANGAN           BATU BARA
# 1  2017  Jan    BALIKPAPAN            PERTAMBANGAN           BATU BARA
# 2  2017  Jan    BALIKPAPAN            PERTAMBANGAN           BATU BARA
# 3  2017  Jan    BALIKPAPAN            PERTAMBANGAN           BATU BARA
# 4  2017  Jan       BANDUNG            PERTAMBANGAN        PASIR & BATU
#
#    Booking Contract  Booking NTF Amount
# 0                 5        5428000000.0
# 1                 5        5428000000.0
# 2                 4         980000000.0
# 3                 4         980000000.0
# 4                 1         950383500.0

# %%
#Mengganti Nama Kolom#

data.rename(columns={'Booking NTF Amount': 'Booking NTF', 'Industry Type Group': 'Industry Type'}, inplace=True)
data
# Out:
#       Year Month       Branch Customer Economy Sector Industry Type  \
# 0     2017  Jan    BALIKPAPAN            PERTAMBANGAN     BATU BARA
# 1     2017  Jan    BALIKPAPAN            PERTAMBANGAN     BATU BARA
# 2     2017  Jan    BALIKPAPAN            PERTAMBANGAN     BATU BARA
# 3     2017  Jan    BALIKPAPAN            PERTAMBANGAN     BATU BARA
# 4     2017  Jan       BANDUNG            PERTAMBANGAN  PASIR & BATU
# ...    ...   ...          ...                     ...           ...
# 9982  2021  Dec     TANGERANG            PERTAMBANGAN  PASIR & BATU
# 9983  2021  Dec     TANGERANG               KONTRUKSI    KONSTRUKSI
# 9984  2021  Dec     TANGERANG               KONTRUKSI    KONSTRUKSI
# 9985  2021  Dec     TANGERANG               KONTRUKSI    KONSTRUKSI
# 9986  2021  Dec     TANGERANG               KONTRUKSI    KONSTRUKSI
#
#       Booking Contract   Booking NTF
# 0                    5  5428000000.0
# 1                    5  5428000000.0
# 2                    4   980000000.0
# 3                    4   980000000.0
# 4                    1   950383500.0
# ...                ...           ...
# 9982                 1  1133403000.0
# 9983                 1   376060000.0
# 9984                 1   376060000.0
# 9985                 2   359380500.0
# 9986                 2   359380500.0
#
# [9987 rows x 7 columns]

# %%
data['Booking NTF'] = data['Booking NTF'].astype(np.int64)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9987 entries, 0 to 9986
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Year                     9987 non-null   int64
#  1   Month                    9987 non-null   object
#  2   Branch                   9987 non-null   object
#  3   Customer Economy Sector  9987 non-null   object
#  4   Industry Type            9987 non-null   object
#  5   Booking Contract         9987 non-null   int64
#  6   Booking NTF              9987 non-null   int64
# dtypes: int64(3), object(4)
# memory usage: 546.3+ KB

# %%
#Menghapus Missing Data#
data = data.dropna()
data.head(5)
# Out:
#    Year Month       Branch Customer Economy Sector Industry Type  \
# 0  2017  Jan    BALIKPAPAN            PERTAMBANGAN     BATU BARA
# 1  2017  Jan    BALIKPAPAN            PERTAMBANGAN     BATU BARA
# 2  2017  Jan    BALIKPAPAN            PERTAMBANGAN     BATU BARA
# 3  2017  Jan    BALIKPAPAN            PERTAMBANGAN     BATU BARA
# 4  2017  Jan       BANDUNG            PERTAMBANGAN  PASIR & BATU
#
#    Booking Contract  Booking NTF
# 0                 5   5428000000
# 1                 5   5428000000
# 2                 4    980000000
# 3                 4    980000000
# 4                 1    950383500

# %%
#Sortir Booking NTF < Rp.500 Juta##

data1 = data[data['Booking NTF'] > 500000000]

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6698 entries, 0 to 9982
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Year                     6698 non-null   int64
#  1   Month                    6698 non-null   object
#  2   Branch                   6698 non-null   object
#  3   Customer Economy Sector  6698 non-null   object
#  4   Industry Type            6698 non-null   object
#  5   Booking Contract         6698 non-null   int64
#  6   Booking NTF              6698 non-null   int64
# dtypes: int64(3), object(4)
# memory usage: 418.6+ KB

# %%
#Pengelompokan Booking NTF Per Cabang#
BokCbg = data.groupby('Branch')

# %%
BokNTF = data1.groupby(['Branch', 'Year'])['Booking NTF'].sum().reset_index()
BokNTF
# Out:
#          Branch  Year   Booking NTF
# 0    BALIKPAPAN  2017  346405835000
# 1    BALIKPAPAN  2018  246404730400
# 2    BALIKPAPAN  2019  117822175000
# 3    BALIKPAPAN  2020   81783887600
# 4    BALIKPAPAN  2021  136196890000
# ..          ...   ...           ...
# 86    TANGERANG  2019  115283776500
# 87    TANGERANG  2020   55014916960
# 88    TANGERANG  2021   66446403408
# 89   YOGYAKARTA  2017   49245528000
# 90   YOGYAKARTA  2018   12318482000
#
# [91 rows x 3 columns]

# %%
#Mengubah Baris Tahun menjadi Kolom#
BokNTF1 = BokNTF.reset_index().pivot(columns= 'Year', index= 'Branch', values='Booking NTF')
BokNTF1
# Out:
# Year                  2017          2018          2019          2020  \
# Branch
#  BALIKPAPAN   3.464058e+11  2.464047e+11  1.178222e+11  8.178389e+10
#  BANDUNG      2.093255e+10  4.328089e+10  4.211534e+10  4.062374e+09
#  BANJARMASIN  1.832444e+11  2.944299e+11  1.314800e+11  7.682940e+10
#  BEKASI       1.968109e+10  7.745543e+10  9.632212e+10  2.212600e+10
#  DENPASAR     4.140008e+10  1.038210e+11  5.704444e+10  1.543484e+10
#  JAKARTA      3.780900e+11  4.350091e+11  4.297137e+11  1.580691e+11
#  JAMBI        1.059534e+11  1.376216e+11  9.865189e+10  3.114906e+10
#  JAYAPURA     8.406528e+10  1.304113e+11  1.543225e+11  4.454937e+10
#  LAMPUNG      4.565083e+10  5.210346e+10  4.260142e+10  3.355498e+10
#  MAKASSAR     1.609836e+11  2.347293e+11  2.612604e+11  7.792230e+10
#  MANADO       1.320210e+11  1.221210e+11  1.569298e+11  3.273390e+10
#  MEDAN        7.046612e+10  1.710764e+11  7.662308e+10  5.337909e+10
#  PALEMBANG    1.306949e+11  1.593649e+11  1.274944e+11  3.253448e+10
#  PEKANBARU    1.830073e+11  2.440437e+11  1.226064e+11  1.278975e+11
#  SAMARINDA    6.125460e+10  2.868313e+11  2.112293e+11  6.469456e+10
#  SEMARANG     4.125034e+10  8.120099e+10  1.073841e+11  5.254466e+10
#  SIDOARJO     3.368258e+09           NaN           NaN           NaN
#  SURABAYA     3.100652e+11  3.528760e+11  3.204522e+11  1.413985e+11
#  TANGERANG    5.634369e+10  1.374472e+11  1.152838e+11  5.501492e+10
#  YOGYAKARTA   4.924553e+10  1.231848e+10           NaN           NaN
#
# Year                  2021
# Branch
#  BALIKPAPAN   1.361969e+11
#  BANDUNG               NaN
#  BANJARMASIN  1.767625e+11
#  BEKASI                NaN
#  DENPASAR     5.200022e+10
#  JAKARTA      3.856936e+11
#  JAMBI        8.202279e+10
#  JAYAPURA     9.628105e+10
#  LAMPUNG      1.581086e+10
#  MAKASSAR     6.964218e+10
#  MANADO       6.482317e+10
#  MEDAN        1.149345e+11
#  PALEMBANG    1.468160e+11
#  PEKANBARU    1.449068e+11
#  SAMARINDA    2.392928e+11
#  SEMARANG     5.079751e+10
#  SIDOARJO              NaN
#  SURABAYA     2.207044e+11
#  TANGERANG    6.644640e+10
#  YOGYAKARTA            NaN

# %%
BokNTF1=BokNTF1.fillna(0)

# %%
# menjumlahkan Booking ntf setiap tahun #
BokNTF1['Total'] = BokNTF1.sum(axis=1)

# %%
# sorting total booking  secara descending(besar ke kecil) #
BokNTF1.sort_values(by='Total', ascending=False, axis=0, inplace=True)

# %%
BokNTF1top5 = BokNTF1.head(5)

# %%
BokNTF1top5
# Out:
# Year                  2017          2018          2019          2020  \
# Branch
#  JAKARTA      3.780900e+11  4.350091e+11  4.297137e+11  1.580691e+11
#  SURABAYA     3.100652e+11  3.528760e+11  3.204522e+11  1.413985e+11
#  BALIKPAPAN   3.464058e+11  2.464047e+11  1.178222e+11  8.178389e+10
#  SAMARINDA    6.125460e+10  2.868313e+11  2.112293e+11  6.469456e+10
#  BANJARMASIN  1.832444e+11  2.944299e+11  1.314800e+11  7.682940e+10
#
# Year                  2021         Total
# Branch
#  JAKARTA      3.856936e+11  1.786576e+12
#  SURABAYA     2.207044e+11  1.345496e+12
#  BALIKPAPAN   1.361969e+11  9.286135e+11
#  SAMARINDA    2.392928e+11  8.633026e+11
#  BANJARMASIN  1.767625e+11  8.627461e+11

# %%
# transpose data frame
BokNTF1top5t = BokNTF1top5.T
BokNTF1top5t
# Out:
# Branch       JAKARTA      SURABAYA    BALIKPAPAN     SAMARINDA   BANJARMASIN
# Year
# 2017    3.780900e+11  3.100652e+11  3.464058e+11  6.125460e+10  1.832444e+11
# 2018    4.350091e+11  3.528760e+11  2.464047e+11  2.868313e+11  2.944299e+11
# 2019    4.297137e+11  3.204522e+11  1.178222e+11  2.112293e+11  1.314800e+11
# 2020    1.580691e+11  1.413985e+11  8.178389e+10  6.469456e+10  7.682940e+10
# 2021    3.856936e+11  2.207044e+11  1.361969e+11  2.392928e+11  1.767625e+11
# Total   1.786576e+12  1.345496e+12  9.286135e+11  8.633026e+11  8.627461e+11

# %%
BokNTF1top = BokNTF1top5t.drop('Total')
BokNTF1top
# Out:
# Branch       JAKARTA      SURABAYA    BALIKPAPAN     SAMARINDA   BANJARMASIN
# Year
# 2017    3.780900e+11  3.100652e+11  3.464058e+11  6.125460e+10  1.832444e+11
# 2018    4.350091e+11  3.528760e+11  2.464047e+11  2.868313e+11  2.944299e+11
# 2019    4.297137e+11  3.204522e+11  1.178222e+11  2.112293e+11  1.314800e+11
# 2020    1.580691e+11  1.413985e+11  8.178389e+10  6.469456e+10  7.682940e+10
# 2021    3.856936e+11  2.207044e+11  1.361969e+11  2.392928e+11  1.767625e+11

# %%
BokNTF1top.plot(kind='area',
stacked=False,
figsize=(20,10),
alpha=0.25,
   )
plt.title('Top 5 Branch Contributed 2017-2021')
plt.ylabel('Booking NTF')
plt.xlabel('Years')

plt.show()

# %% [markdown]
# QUESTION 1
#
# APAKAH TERDAPAT PERBEDAAN JUMLAH BOOKING NTF DARI TAHUN 2017-2021?
# ==DAPAT DILIHAT PADA DIAGRAM DIATAS JUMLAH BOOKING DI CABANG TERLIHAT PERBEDAAN DI SETIAP TAHUNNYA==

# %% [markdown]
# QUESTION 3
#
# APAKAH ADA TREND TERTENTU?ADA YANG BOOKINGNYA NAIK,TURUN ATAU STAGNAN?
# == BOOKING DI SETIAP TAHUNNYA MENGALAMI TREND BERBEDA. TERUTAMA PADA TAHUN 2020 MENGALAMI PENURUNAN JUMLAH BOOKING DIKARENAKAN PANDEMI COVID YANG MENYEBABKAN PENJUALAN ALAT BERAT MENURUN TAJAM ==

# %% [markdown]
# ==MELIHAT CUSTOMER DARI SECTOR INDUSTRY MANA YANG PALING BANYAK BOOKING CONTRACTNYA==

# %%
data1.head()
# Out:
#    Year Month       Branch Customer Economy Sector Industry Type  \
# 0  2017  Jan    BALIKPAPAN            PERTAMBANGAN     BATU BARA
# 1  2017  Jan    BALIKPAPAN            PERTAMBANGAN     BATU BARA
# 2  2017  Jan    BALIKPAPAN            PERTAMBANGAN     BATU BARA
# 3  2017  Jan    BALIKPAPAN            PERTAMBANGAN     BATU BARA
# 4  2017  Jan       BANDUNG            PERTAMBANGAN  PASIR & BATU
#
#    Booking Contract  Booking NTF
# 0                 5   5428000000
# 1                 5   5428000000
# 2                 4    980000000
# 3                 4    980000000
# 4                 1    950383500

# %%
Debsector = data1.reset_index()[['Industry Type', 'Booking Contract']].groupby(['Industry Type']).agg({'Booking Contract': 'sum'})
Debsector.head()
# Out:
#                Booking Contract
# Industry Type
# BATU BARA                  2012
# KONSTRUKSI                 5167
# MANUFACTURING               809
# NICKEL                      554
# OTHER MINING                581

# %%
Debsector.plot(kind = 'barh', figsize=(15,7), color='orange')
plt.title('Industry Type Customer 2017-2021')
plt.xlabel('Booking Contract')
plt.ylabel('Industry Type')
plt.show()

# %% [markdown]
# QUESTION 2
#
# APAKAH TERDAPAT PERBEDAAN JENIS INDUSTRI DARI CUSTOMER YANG MELAKUKAN BOOKING?
# == YA, TERDAPAT PERBEDAAN DARI MASING-MASING CUSTOMER YANG MELAKUKAN BOOKING. NAMUN SEPANJANG TAHUN 2017-2021 DI DOMINASI OLEH CUSTOMER DARI SEKTOR ECONOMY KONSTRUKSI ==

# %%
data1.value_counts('Branch')
# Out:
# Branch
#  JAKARTA        862
#  SURABAYA       840
#  PALEMBANG      518
#  MAKASSAR       513
#  PEKANBARU      457
#  BANJARMASIN    407
#  BALIKPAPAN     384
#  SAMARINDA      361
#  TANGERANG      331
#  MANADO         315
#  JAMBI          309
#  MEDAN          304
#  JAYAPURA       273
#  SEMARANG       231
#  DENPASAR       166
#  BEKASI         147
#  LAMPUNG        129
#  BANDUNG        106
#  YOGYAKARTA      41
#  SIDOARJO         4
# dtype: int64

# %%
data1.groupby('Branch').mean()
# Out:
#                      Year  Booking Contract   Booking NTF
# Branch
#  BALIKPAPAN   2018.515625          2.552083  2.418264e+09
#  BANDUNG      2018.235849          1.367925  1.041426e+09
#  BANJARMASIN  2018.813268          2.076167  2.119769e+09
#  BEKASI       2018.448980          1.959184  1.466562e+09
#  DENPASAR     2018.897590          1.753012  1.624703e+09
#  JAKARTA      2018.872390          2.641531  2.072593e+09
#  JAMBI        2018.754045          1.618123  1.473782e+09
#  JAYAPURA     2018.641026          1.985348  1.866775e+09
#  LAMPUNG      2018.643411          2.069767  1.470710e+09
#  MAKASSAR     2018.791423          1.740741  1.568300e+09
#  MANADO       2018.574603          1.638095  1.614695e+09
#  MEDAN        2019.062500          2.483553  1.600260e+09
#  PALEMBANG    2018.891892          1.611969  1.152326e+09
#  PEKANBARU    2018.908096          2.192560  1.799697e+09
#  SAMARINDA    2018.869806          2.675900  2.391420e+09
#  SEMARANG     2018.965368          1.735931  1.442328e+09
#  SIDOARJO     2017.000000          1.500000  8.420645e+08
#  SURABAYA     2018.786905          2.433333  1.601781e+09
#  TANGERANG    2018.960725          1.619335  1.300713e+09
#  YOGYAKARTA   2017.195122          2.097561  1.501561e+09

# %%
data1.groupby('Branch').median()
# Out:
#                 Year  Booking Contract   Booking NTF
# Branch
#  BALIKPAPAN   2018.0               2.0  1.451875e+09
#  BANDUNG      2018.0               1.0  9.979150e+08
#  BANJARMASIN  2019.0               1.0  1.233035e+09
#  BEKASI       2019.0               1.0  1.127600e+09
#  DENPASAR     2019.0               1.0  1.165305e+09
#  JAKARTA      2019.0               2.0  1.270410e+09
#  JAMBI        2019.0               1.0  1.225862e+09
#  JAYAPURA     2018.0               1.0  1.319870e+09
#  LAMPUNG      2018.0               2.0  8.953000e+08
#  MAKASSAR     2019.0               1.0  1.044100e+09
#  MANADO       2019.0               1.0  1.218140e+09
#  MEDAN        2019.0               2.0  1.086460e+09
#  PALEMBANG    2019.0               1.0  9.608722e+08
#  PEKANBARU    2019.0               1.0  1.019072e+09
#  SAMARINDA    2019.0               1.0  1.321550e+09
#  SEMARANG     2019.0               1.0  1.262900e+09
#  SIDOARJO     2017.0               1.5  8.420645e+08
#  SURABAYA     2019.0               2.0  1.108500e+09
#  TANGERANG    2019.0               1.0  9.616900e+08
#  YOGYAKARTA   2017.0               2.0  1.296505e+09

# %%
data1.groupby('Branch').agg(pd.Series.mode)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11640\2078269356.py:1: FutureWarning: ['Booking NTF'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   data1.groupby('Branch').agg(pd.Series.mode)
#                       Year         Month         Customer Economy Sector  \
# Branch
#  BALIKPAPAN           2017          Sep                     PERTAMBANGAN
#  BANDUNG              2018  [Dec , Oct ]                       KONTRUKSI
#  BANJARMASIN          2018          Oct                     PERTAMBANGAN
#  BEKASI               2019          Feb                        KONTRUKSI
#  DENPASAR             2018          Sep                        KONTRUKSI
#  JAKARTA              2019          Dec                        KONTRUKSI
#  JAMBI        [2018, 2019]          Sep                        KONTRUKSI
#  JAYAPURA             2018  [Mar , Oct ]                       KONTRUKSI
#  LAMPUNG              2018          Oct                        KONTRUKSI
#  MAKASSAR             2019          Oct                        KONTRUKSI
#  MANADO               2019          Sep                        KONTRUKSI
#  MEDAN        [2018, 2021]          Nov                        KONTRUKSI
#  PALEMBANG            2021          May                     PERTAMBANGAN
#  PEKANBARU    [2018, 2019]          Aug                       PERHUTANAN
#  SAMARINDA            2018          Feb                     PERTAMBANGAN
#  SEMARANG             2019          Sep                     PERTAMBANGAN
#  SIDOARJO             2017  [Feb , Mar ]  [INDUSTRI/MANUFACTURING, JASA]
#  SURABAYA             2018          Nov                        KONTRUKSI
#  TANGERANG            2019          Aug                     PERTAMBANGAN
#  YOGYAKARTA           2017          Oct                     PERTAMBANGAN
#
#                         Industry Type Booking Contract
# Branch
#  BALIKPAPAN                 BATU BARA                1
#  BANDUNG                   KONSTRUKSI                1
#  BANJARMASIN                BATU BARA                1
#  BEKASI                    KONSTRUKSI                1
#  DENPASAR                  KONSTRUKSI                1
#  JAKARTA                   KONSTRUKSI                1
#  JAMBI                     KONSTRUKSI                1
#  JAYAPURA                  KONSTRUKSI                1
#  LAMPUNG                   KONSTRUKSI                1
#  MAKASSAR                  KONSTRUKSI                1
#  MANADO                    KONSTRUKSI                1
#  MEDAN                     KONSTRUKSI                1
#  PALEMBANG               OTHER MINING                1
#  PEKANBARU                 PERKEBUNAN                1
#  SAMARINDA                  BATU BARA                1
#  SEMARANG                PASIR & BATU                1
#  SIDOARJO     [MANUFACTURING, OTHERS]           [1, 2]
#  SURABAYA                  KONSTRUKSI                1
#  TANGERANG               PASIR & BATU                1
#  YOGYAKARTA              PASIR & BATU                1

# %%
data1.groupby('Branch')['Booking NTF'].max(), data.groupby('Branch') ['Booking NTF'].min()
# Out:
# (Branch
#   BALIKPAPAN     13680000000
#   BANDUNG         2940397500
#   BANJARMASIN    22030965909
#   BEKASI          4620100000
#   DENPASAR       15854640000
#   JAKARTA        18389925000
#   JAMBI           6908270000
#   JAYAPURA       15461108000
#   LAMPUNG        11385000000
#   MAKASSAR       18971232500
#   MANADO         10065860000
#   MEDAN          15342801000
#   PALEMBANG       8835750000
#   PEKANBARU      15800970000
#   SAMARINDA      18900000000
#   SEMARANG        5477520000
#   SIDOARJO         954800000
#   SURABAYA       15634746000
#   TANGERANG       9609274000
#   YOGYAKARTA      3802560000
#  Name: Booking NTF, dtype: int64,
#  Branch
#   BALIKPAPAN     133350000
#   BANDUNG         70000000
#   BANJARMASIN    165430000
#   BEKASI         103489000
#   DENPASAR        28166292
#   JAKARTA         90201800
#   JAMBI           26239840
#   JAYAPURA       108500000
#   LAMPUNG        100750000
#   MAKASSAR       147482093
#   MANADO         100000000
#   MEDAN          117000000
#   PALEMBANG      104000000
#   PEKANBARU       49231171
#   SAMARINDA      148363000
#   SEMARANG        99240000
#   SIDOARJO       281550000
#   SURABAYA        76000000
#   TANGERANG      142066000
#   YOGYAKARTA     150000000
#  Name: Booking NTF, dtype: int64)

# %%
data1.groupby('Branch').var()
# Out:
#                   Year  Booking Contract   Booking NTF
# Branch
#  BALIKPAPAN   2.010199          5.955505  5.462603e+18
#  BANDUNG      0.658131          0.520485  1.669882e+17
#  BANJARMASIN  1.999528          5.375958  7.664325e+18
#  BEKASI       0.687448          2.285994  1.027062e+18
#  DENPASAR     2.043994          2.344688  3.333694e+18
#  JAKARTA      1.888459          7.990979  6.009507e+18
#  JAMBI        1.815933          1.054995  8.805026e+17
#  JAYAPURA     1.664781          4.183608  3.452616e+18
#  LAMPUNG      1.824976          2.737282  2.784401e+18
#  MAKASSAR     1.657583          2.001013  2.547917e+18
#  MANADO       1.550945          1.199818  1.731628e+18
#  MEDAN        2.157797         12.105339  2.961441e+18
#  PALEMBANG    2.154634          1.626704  7.852030e+17
#  PEKANBARU    2.026623          3.945295  4.593502e+18
#  SAMARINDA    1.796891         16.514112  8.036873e+18
#  SEMARANG     1.616187          1.082138  7.899460e+17
#  SIDOARJO     0.000000          0.333333  1.694572e+16
#  SURABAYA     1.896133          6.186253  2.695062e+18
#  TANGERANG    1.698453          1.163746  1.468685e+18
#  YOGYAKARTA   0.160976          1.490244  6.547167e+17

# %%
data1.groupby('Branch').std(ddof=1)
# Out:
#                   Year  Booking Contract   Booking NTF
# Branch
#  BALIKPAPAN   1.417815          2.440390  2.337221e+09
#  BANDUNG      0.811253          0.721447  4.086419e+08
#  BANJARMASIN  1.414047          2.318611  2.768452e+09
#  BEKASI       0.829125          1.511950  1.013441e+09
#  DENPASAR     1.429683          1.531237  1.825841e+09
#  JAKARTA      1.374212          2.826832  2.451430e+09
#  JAMBI        1.347566          1.027130  9.383510e+08
#  JAYAPURA     1.290264          2.045387  1.858122e+09
#  LAMPUNG      1.350917          1.654473  1.668652e+09
#  MAKASSAR     1.287471          1.414572  1.596220e+09
#  MANADO       1.245370          1.095362  1.315913e+09
#  MEDAN        1.468944          3.479273  1.720884e+09
#  PALEMBANG    1.467867          1.275423  8.861168e+08
#  PEKANBARU    1.423595          1.986277  2.143246e+09
#  SAMARINDA    1.340482          4.063756  2.834938e+09
#  SEMARANG     1.271293          1.040259  8.887891e+08
#  SIDOARJO     0.000000          0.577350  1.301757e+08
#  SURABAYA     1.377002          2.487218  1.641664e+09
#  TANGERANG    1.303247          1.078771  1.211893e+09
#  YOGYAKARTA   0.401218          1.220755  8.091456e+08

# %%
#menghitung CI untuk Booking NTF di  Cabang
Booking = data1[{'Branch', 'Booking NTF'}]
print(Booking.shape)
Booking.head()
# Out:
# (6698, 2)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11640\207872216.py:2: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   Booking = data1[{'Branch', 'Booking NTF'}]
#    Booking NTF       Branch
# 0   5428000000   BALIKPAPAN
# 1   5428000000   BALIKPAPAN
# 2    980000000   BALIKPAPAN
# 3    980000000   BALIKPAPAN
# 4    950383500      BANDUNG

# %%
Booking.groupby('Branch').agg({'Booking NTF': [np.mean, np.std, np.size]})
# Out:
#                Booking NTF
#                       mean           std size
# Branch
#  BALIKPAPAN   2.418264e+09  2.337221e+09  384
#  BANDUNG      1.041426e+09  4.086419e+08  106
#  BANJARMASIN  2.119769e+09  2.768452e+09  407
#  BEKASI       1.466562e+09  1.013441e+09  147
#  DENPASAR     1.624703e+09  1.825841e+09  166
#  JAKARTA      2.072593e+09  2.451430e+09  862
#  JAMBI        1.473782e+09  9.383510e+08  309
#  JAYAPURA     1.866775e+09  1.858122e+09  273
#  LAMPUNG      1.470710e+09  1.668652e+09  129
#  MAKASSAR     1.568300e+09  1.596220e+09  513
#  MANADO       1.614695e+09  1.315913e+09  315
#  MEDAN        1.600260e+09  1.720884e+09  304
#  PALEMBANG    1.152326e+09  8.861168e+08  518
#  PEKANBARU    1.799697e+09  2.143246e+09  457
#  SAMARINDA    2.391420e+09  2.834938e+09  361
#  SEMARANG     1.442328e+09  8.887891e+08  231
#  SIDOARJO     8.420645e+08  1.301757e+08    4
#  SURABAYA     1.601781e+09  1.641664e+09  840
#  TANGERANG    1.300713e+09  1.211893e+09  331
#  YOGYAKARTA   1.501561e+09  8.091456e+08   41

# %%
mean_JKT = 2072593 # Mean Bok NTF di Jakarta
sd_JKT = 2451430   # Std Dev Bok NTF di Jakarta
n_JKT = 862      # Total jumlah penjualan rumah di manhattan
z_JKT = 1.96

# %%
se_JKT = sd_JKT / np.sqrt(n_JKT)
se_JKT
# Out:
# 83496.03714633128

# %%
Icb = mean_JKT - z_JKT* se_JKT
ucb = mean_JKT + z_JKT* se_JKT
Icb, ucb
# Out:
# (1908940.7671931908, 2236245.2328068092)

# %%
import statsmodels.api as sm

# %%
surabaya = data1[data1['Branch'] == 'SURABAYA']
jakarta = data1[data1['Branch'] == 'JAKARTA']

n_SBY = len(surabaya)
mean_SBY = surabaya['Booking NTF'].mean()
std_SBY = surabaya['Booking NTF'].std()

n_JKT = len(jakarta)
mean_JKT = jakarta['Booking NTF'].mean()
std_JKT = jakarta['Booking NTF'].std()

print(n_SBY, mean_SBY, std_SBY)
print(n_JKT, mean_JKT, std_JKT)
# Out:
# 0 nan nan
# 0 nan nan
